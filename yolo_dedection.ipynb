# %%
# !pip install -qU transformers ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 902.2/902.2 kB 47.0 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

model = YOLO('yolo11m-seg.pt')
# Out:
# ...
# 100%|██████████| 43.3M/43.3M [00:01<00:00, 41.5MB/s]

# %%
# !unzip Dentex2.v2i.yolov8.zip -d data/
# Out:
# Archive:  Dentex2.v2i.yolov8.zip
#  extracting: data/README.dataset.txt
#  extracting: data/README.roboflow.txt
#  extracting: data/data.yaml
#    creating: data/test/
#    creating: data/test/images/
#  extracting: data/test/images/train_516_png.rf.5b83bd88e819767cbaedcd1511d2ee1f.jpg
#  extracting: data/test/images/train_526_png.rf.d53c7caeb627dc2d17c9c4e0b2a31f10.jpg
#  extracting: data/test/images/train_537_png.rf.a6c7767ab86c1b7eb6b18d128676fa8f.jpg
#  extracting: data/test/images/train_539_png.rf.99f48ed48b5db8009178d021313adf7b.jpg
#  extracting: data/test/images/train_547_png.rf.9aeb09e22e1cc5229fd233fc4d719138.jpg
#  extracting: data/test/images/train_548_png.rf.a51319d1d8207f73f07fa2341c6d467c.jpg
#  extracting: data/test/images/train_553_png.rf.2dba133e6c2763d29a2c6c5f0b77b482.jpg
#  extracting: data/test/images/train_554_png.rf.c1ffb20d66b513aa9e99f33b974c925c.jpg
#  extracting: data/test/images/train_555_png.rf.66834e30f370130ad2e2d24000825e9a.jpg
# ...

# %%
results = model.train(data='/content/data/data.yaml', epochs=30, imgsz=640, device=0)
# Out:
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('/content/runs/segment/train3/weights/best.pt')
image = "/content/data/test/images/train_516_png.rf.5b83bd88e819767cbaedcd1511d2ee1f.jpg"
result = model.predict(image)
# Out:
# image 1/1 /content/data/test/images/train_516_png.rf.5b83bd88e819767cbaedcd1511d2ee1f.jpg: 320x640 1 11, 1 12, 1 13, 1 14, 2 15s, 1 16, 1 17, 2 21s, 1 22, 1 23, 1 24, 1 25, 1 26, 1 27, 1 31, 1 32, 2 33s, 1 34, 1 35, 1 36, 1 37, 1 41, 2 42s, 2 43s, 1 44, 1 45, 1 46, 1 47, 109.8ms
# Speed: 7.8ms preprocess, 109.8ms inference, 21.8ms postprocess per image at shape (1, 3, 320, 640)

# %%
for r in result:
    frame = r.plot()
    cv2_imshow(frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1976x976>

# %%
# !zip yolo.zip -r /content/runs
# Out:
# updating: content/runs/ (stored 0%)
#   adding: content/runs/segment/ (stored 0%)
#   adding: content/runs/segment/train/ (stored 0%)
#   adding: content/runs/segment/train/args.yaml (deflated 53%)
#   adding: content/runs/segment/train/weights/ (stored 0%)
#   adding: content/runs/segment/train4/ (stored 0%)
#   adding: content/runs/segment/train4/args.yaml (deflated 53%)
#   adding: content/runs/segment/train4/val_batch1_pred.jpg (deflated 9%)
#   adding: content/runs/segment/train4/labels_correlogram.jpg (deflated 34%)
#   adding: content/runs/segment/train4/train_batch641.jpg (deflated 16%)
#   adding: content/runs/segment/train4/results.csv (deflated 61%)
#   adding: content/runs/segment/train4/train_batch1.jpg (deflated 4%)
#   adding: content/runs/segment/train4/labels.jpg (deflated 39%)
#   adding: content/runs/segment/train4/results.png (deflated 6%)
#   adding: content/runs/segment/train4/events.out.tfevents.1735038428.22fbc4407b8f.522.2 (deflated 93%)
# ...
